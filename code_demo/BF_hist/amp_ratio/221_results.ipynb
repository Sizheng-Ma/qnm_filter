# %%
import numpy as np
import matplotlib.pyplot as pl
from matplotlib.offsetbox import AnchoredText

# %% [markdown]
# ## NNI

# %%
result = np.loadtxt('./results/ratio=1_ALL.dat')
[SNRtot, SNR221, evidence220, evidence221, evidence220_221, nofilter] = result.T
sort_idx = np.argsort(SNRtot)
[SNRtot, SNR221, evidence220, evidence221, evidence220_221, nofilter] = result[sort_idx].T

# %% [markdown]
# ## nofilter

# %%
pl.plot(SNRtot**2, evidence220_221 - nofilter, 'o', c='tab:blue')
pl.xlabel("Total SNR")
pl.ylabel("ln(BF): 220+221:nofilter")
pl.title("220+221 NNI injection")
# Out:
# Text(0.5, 1.0, '220+221 NNI injection')

# %%
slope_arr = []
for i in range(len(SNRtot)//5):
    slope, _ = np.polyfit((SNRtot**2)[5*i:5*i+5], (evidence220_221 - nofilter)[5*i:5*i+5], deg=1, cov=False)
    slope_arr.append(slope)
pl.semilogx(SNRtot[::5], slope_arr)

pl.title("Slope of 5 consecutive points at different SNRs")
pl.xlabel("Total SNR")
pl.ylabel("Slope")
pl.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
slope_arr = []
sort_idx = np.argsort(SNRtot)
for i in range(len(SNRtot)//5):
    slope, _ = np.polyfit((SNRtot**2)[5*i:5*i+5], nofilter[5*i:5*i+5], deg=1, cov=False)
    slope_arr.append(slope)
pl.semilogx(SNRtot[::5], slope_arr)

pl.title("Slope of 5 consecutive points at different SNRs")
pl.xlabel("Total SNR")
pl.ylabel("Slope")
pl.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
slope_arr = []
sort_idx = np.argsort(SNRtot)
for i in range(len(SNRtot)//5):
    slope, _ = np.polyfit((SNRtot**2)[5*i:5*i+5], -evidence220_221[5*i:5*i+5], deg=1, cov=False)
    slope_arr.append(slope)
pl.semilogx(SNRtot[::5], slope_arr)

pl.title("Slope of 5 consecutive points at different SNRs")
pl.xlabel("Total SNR")
pl.ylabel("Slope")
pl.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
slope_arr = []
for i in range(len(SNRtot)//5):
    slope, _ = np.polyfit((SNRtot**2)[5*i:5*i+5], (evidence220_221 - evidence220)[5*i:5*i+5], deg=1, cov=False)
    slope_arr.append(slope)
pl.semilogx(SNRtot[::5], slope_arr)

pl.title("Slope of 5 consecutive points at different SNRs")
pl.xlabel("Total SNR")
pl.ylabel("Slope")
pl.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
pl.plot(SNR221**2, evidence220_221 - evidence220, 'o', c='tab:blue')

# %%
pl.semilogx(SNR221**2, evidence220, 'o', c='tab:blue')

# %%
slope_arr = []
sort_idx = np.argsort(SNRtot)
for i in range(len(SNRtot)//5):
    slope, _ = np.polyfit((SNRtot**2)[5*i:5*i+5], evidence220[5*i:5*i+5], deg=1, cov=False)
    slope_arr.append(slope)
pl.semilogx(SNRtot[::5], slope_arr)

pl.title("Slope of 5 consecutive points at different SNRs")
pl.xlabel("Total SNR")
pl.ylabel("Slope")
pl.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
slope_arr = []
for i in range(len(SNRtot)//5):
    slope, _ = np.polyfit((SNR221**2)[5*i:5*i+5], (evidence220_221-evidence220)[5*i:5*i+5], deg=1, cov=False)
    slope_arr.append(slope)
pl.semilogx(SNR221[::5], slope_arr)

pl.title("Slope of 5 consecutive points at different SNRs")
pl.xlabel("Total SNR")
pl.ylabel("Slope")
pl.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
slope_arr = []
sort_idx = np.argsort(SNR221)
log_snr = np.log10(SNR221[sort_idx])
log_BF = np.log10((evidence220_221-evidence220)[sort_idx])
for i in range(len(SNRtot)//5):
    slope, _ = np.polyfit(log_snr[5*i:5*i+5], log_BF[5*i:5*i+5], deg=1, cov=False)
    slope_arr.append(slope)
pl.semilogx(10**log_snr[::5], slope_arr)

pl.title("Slope of 5 consecutive points at different SNRs")
pl.xlabel("Total SNR")
pl.ylabel("Slope")
pl.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
pl.loglog(SNRtot, -nofilter, 'o', c='tab:blue')
pl.axvline(6, c='orange', ls='--')
pl.axvline(12, c='r', ls='--')
pl.xlabel("Total SNR")
pl.ylabel("ln(evidence) of nofilter")
# Out:
# Text(0, 0.5, 'ln(evidence) of nofilter')

# %%
# slope_arr = []
# sort_idx = np.argsort(SNRtot)
# log_snr = np.log10(SNRtot[sort_idx])
# log_BF = np.log10((-nofilter)[sort_idx])
# for i in range(len(SNRtot)//5):
#     slope, _ = np.polyfit(log_snr[5*i:5*i+5], log_BF[5*i:5*i+5], deg=1, cov=False)
#     slope_arr.append(slope)
# pl.semilogx(10**log_snr[::5], slope_arr)

# # pl.title("Slope of 5 consecutive points at different SNRs")
# # pl.xlabel("Total SNR")
# # pl.ylabel("Slope")
# # pl.legend()

# slope_arr1 = []
# sort_idx = np.argsort(SNRtot)
# log_snr = np.log10(SNRtot[sort_idx])
# log_BF = np.log10((evidence220_221-nofilter)[sort_idx])
# for i in range(len(SNRtot)//5):
#     slope, _ = np.polyfit(log_snr[5*i:5*i+5], log_BF[5*i:5*i+5], deg=1, cov=False)
#     slope_arr1.append(slope)
# pl.semilogx(10**log_snr[::5], slope_arr1)

# # pl.semilogx(10**log_snr[::5], np.divide(slope_arr1,slope_arr))

# pl.title("Slope of 5 consecutive points at different SNRs")
# pl.xlabel("Total SNR")
# pl.ylabel("Slope")
# pl.legend()

# %%
fig, axs = pl.subplots(2, figsize=(10,8), sharex = True)
pl.subplots_adjust(wspace=0, hspace=0)

result = np.loadtxt('./results/221_amp_ratio=1_ALL.dat')
[SNRtot, SNR221, SNR220, evidence220, evidence221, evidence220_221, nofilter] = result.T
axs[0].loglog(SNR221, -evidence220, 'o', label='amp_ratio=1')
axs[0].set_ylabel("-ln(Evidence) of 220")

axs[1].loglog(SNR221, evidence220_221-evidence220, 'o')
axs[1].set_ylabel("ln(BF) of 220+221:220")
axs[1].set_xlabel("221 SNR")

result = np.loadtxt('./results/221_amp_ratio=10_ALL.dat')
[SNRtot, SNR221, SNR220, evidence220, evidence221, evidence220_221, nofilter] = result.T
axs[0].loglog(SNR221, -evidence220, 'o', label='amp_ratio=10')
axs[1].loglog(SNR221, evidence220_221-evidence220, 'o')
axs[0].legend()

# %%
pl.loglog(SNR221, evidence220_221 - evidence220, 'o', c='tab:blue')

# %%
slope_arr = []
sort_idx = np.argsort(SNR221)
log_snr = np.log10(SNR221[sort_idx])
log_BF = np.log10((evidence220_221-evidence330)[sort_idx])
for i in range(len(SNRtot)//5):
    slope, _ = np.polyfit(log_snr[5*i:5*i+5], log_BF[5*i:5*i+5], deg=1, cov=False)
    slope_arr.append(slope)
pl.semilogx(10**log_snr[::5], slope_arr)

pl.title("Slope of 5 consecutive points at different SNRs")
pl.xlabel("Total SNR")
pl.ylabel("Slope")
pl.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Diff amp_ratio

# %%
result = np.loadtxt('./results/221_amp_ratio=0.1_ALL.dat')
[SNRtot, SNR221, SNR220, evidence220, evidence221, evidence220_221, nofilter] = result.T

# %%
pl.loglog(SNR221, evidence220, 'o')

# %%
pl.loglog(SNR221, evidence220_221-evidence221, 'o')
