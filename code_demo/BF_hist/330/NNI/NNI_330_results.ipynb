# %%
import matplotlib.pyplot as pl
import numpy as np

# %%
data = np.loadtxt('./results/330_NNI_random_mass_ALL.dat')
[SNRtot, SNR330_res, SNR330, evidence220_330, evidence220, nofilter] = data.T

# %%
data = np.loadtxt('./results/330_NNI_random_mass_ALL.dat')
[SNRtot, SNR330_res, SNR330, evidence220_330, evidence220, nofilter] = data.T
pl.plot(SNR330_res, evidence220_330 - evidence220, 'o')

data = np.loadtxt('./results/330_NNI_random_mass_amp_ALL.dat')
[SNRtot, SNR330_res, SNR330, evidence220_330, evidence220, nofilter] = data.T
pl.plot(SNR330_res, evidence220_330 - evidence220, 'o')
pl.axhline(3.865, c='r', ls='--')

# %%
data = np.loadtxt('./results/330_NNI_chi=0.1_random_amp_phase_ALL.dat')
[SNRtot, SNR330_res, SNR330, evidence220_330, evidence220, nofilter] = data.T
pl.plot(SNR330, evidence220_330 - evidence220, 'o')

data = np.loadtxt('./results/330_NNI_chi=0.4_random_amp_phase_ALL.dat')
[SNRtot, SNR330_res, SNR330, evidence220_330, evidence220, nofilter] = data.T
pl.plot(SNR330, evidence220_330 - evidence220, 'o')
pl.axhline(3.865, c='r', ls='--')
pl.xlim(0, 15)
pl.ylim(0, 30)
# Out:
# (0.0, 30.0)
